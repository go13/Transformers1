# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 15000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.1
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('F://workspace//ai//Transformers1//input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6700, val loss 2.6801
# step 200: train loss 2.5187, val loss 2.5149
# step 300: train loss 2.4354, val loss 2.4494
# step 400: train loss 2.3681, val loss 2.3746
# step 500: train loss 2.3209, val loss 2.3350
# step 600: train loss 2.2707, val loss 2.2743
# step 700: train loss 2.2354, val loss 2.2475
# step 800: train loss 2.1952, val loss 2.2137
# step 900: train loss 2.1582, val loss 2.1754
# step 1000: train loss 2.1364, val loss 2.1477
# step 1100: train loss 2.1047, val loss 2.1393
# step 1200: train loss 2.0837, val loss 2.1085
# step 1300: train loss 2.0718, val loss 2.0983
# step 1400: train loss 2.0371, val loss 2.0665
# step 1500: train loss 2.0115, val loss 2.0584
# step 1600: train loss 1.9985, val loss 2.0617
# step 1700: train loss 1.9902, val loss 2.0418
# step 1800: train loss 1.9613, val loss 2.0345
# step 1900: train loss 1.9537, val loss 2.0119
# step 2000: train loss 1.9390, val loss 2.0180
# step 2100: train loss 1.9244, val loss 2.0079
# step 2200: train loss 1.9112, val loss 1.9882
# step 2300: train loss 1.9071, val loss 1.9884
# step 2400: train loss 1.8964, val loss 1.9712
# step 2500: train loss 1.8751, val loss 1.9726
# step 2600: train loss 1.8790, val loss 1.9629
# step 2700: train loss 1.8699, val loss 1.9725
# step 2800: train loss 1.8590, val loss 1.9550
# step 2900: train loss 1.8587, val loss 1.9656
# step 3000: train loss 1.8468, val loss 1.9490
# step 3100: train loss 1.8237, val loss 1.9472
# step 3200: train loss 1.8075, val loss 1.9303
# step 3300: train loss 1.8110, val loss 1.9321
# step 3400: train loss 1.8120, val loss 1.9246
# step 3500: train loss 1.7985, val loss 1.9180
# step 3600: train loss 1.7838, val loss 1.9192
# step 3700: train loss 1.7889, val loss 1.9162
# step 3800: train loss 1.7755, val loss 1.9198
# step 3900: train loss 1.7782, val loss 1.9014
# step 4000: train loss 1.7680, val loss 1.8923
# step 4100: train loss 1.7664, val loss 1.9028
# step 4200: train loss 1.7617, val loss 1.8971
# step 4300: train loss 1.7610, val loss 1.8843
# step 4400: train loss 1.7601, val loss 1.9000
# step 4500: train loss 1.7428, val loss 1.8820
# step 4600: train loss 1.7432, val loss 1.8732
# step 4700: train loss 1.7398, val loss 1.8767
# step 4800: train loss 1.7274, val loss 1.8783
# step 4900: train loss 1.7273, val loss 1.8746
# step 5000: train loss 1.7210, val loss 1.8553
# step 5100: train loss 1.7215, val loss 1.8628
# step 5200: train loss 1.7115, val loss 1.8553
# step 5300: train loss 1.7177, val loss 1.8494
# step 5400: train loss 1.7064, val loss 1.8521
# step 5500: train loss 1.7022, val loss 1.8392
# step 5600: train loss 1.7129, val loss 1.8564
# step 5700: train loss 1.7014, val loss 1.8443
# step 5800: train loss 1.6947, val loss 1.8400
# step 5900: train loss 1.7028, val loss 1.8440
# step 6000: train loss 1.6954, val loss 1.8389
# step 6100: train loss 1.6967, val loss 1.8352
# step 6200: train loss 1.6976, val loss 1.8361
# step 6300: train loss 1.6850, val loss 1.8431
# step 6400: train loss 1.6779, val loss 1.8355
# step 6500: train loss 1.6787, val loss 1.8220
# step 6600: train loss 1.6766, val loss 1.8225
# step 6700: train loss 1.6750, val loss 1.8293
# step 6800: train loss 1.6775, val loss 1.8324
# step 6900: train loss 1.6723, val loss 1.8202
# step 7000: train loss 1.6647, val loss 1.8157
# step 7100: train loss 1.6699, val loss 1.8174
# step 7200: train loss 1.6586, val loss 1.8264
# step 7300: train loss 1.6597, val loss 1.8111
# step 7400: train loss 1.6612, val loss 1.8216
# step 7500: train loss 1.6470, val loss 1.8180
# step 7600: train loss 1.6551, val loss 1.8190
# step 7700: train loss 1.6480, val loss 1.8076
# step 7800: train loss 1.6555, val loss 1.8037
# step 7900: train loss 1.6557, val loss 1.8124
# step 8000: train loss 1.6450, val loss 1.8083
# step 8100: train loss 1.6497, val loss 1.8081
# step 8200: train loss 1.6540, val loss 1.8143
# step 8300: train loss 1.6494, val loss 1.8086
# step 8400: train loss 1.6427, val loss 1.8047
# step 8500: train loss 1.6417, val loss 1.8045
# step 8600: train loss 1.6424, val loss 1.8103
# step 8700: train loss 1.6372, val loss 1.8071
# step 8800: train loss 1.6209, val loss 1.7993
# step 8900: train loss 1.6375, val loss 1.7888
# step 9000: train loss 1.6323, val loss 1.7914
# step 9100: train loss 1.6273, val loss 1.7899
# step 9200: train loss 1.6371, val loss 1.7942
# step 9300: train loss 1.6227, val loss 1.7857
# step 9400: train loss 1.6239, val loss 1.7804
# step 9500: train loss 1.6250, val loss 1.7987
# step 9600: train loss 1.6250, val loss 1.7875
# step 9700: train loss 1.6212, val loss 1.7767
# step 9800: train loss 1.6094, val loss 1.7899
# step 9900: train loss 1.6199, val loss 1.7876
# step 10000: train loss 1.6163, val loss 1.7785
# step 10100: train loss 1.6188, val loss 1.7928
# step 10200: train loss 1.6087, val loss 1.7727
# step 10300: train loss 1.6061, val loss 1.7736
# step 10400: train loss 1.6124, val loss 1.7810
# step 10500: train loss 1.6129, val loss 1.7649
# step 10600: train loss 1.6117, val loss 1.7705
# step 10700: train loss 1.6109, val loss 1.7824
# step 10800: train loss 1.6097, val loss 1.7885
# step 10900: train loss 1.6006, val loss 1.7781
# step 11000: train loss 1.5988, val loss 1.7773
# step 11100: train loss 1.5966, val loss 1.7683
# step 11200: train loss 1.6022, val loss 1.7627
# step 11300: train loss 1.6002, val loss 1.7763
# step 11400: train loss 1.6048, val loss 1.7645
# step 11500: train loss 1.5993, val loss 1.7503
# step 11600: train loss 1.6001, val loss 1.7463
# step 11700: train loss 1.5898, val loss 1.7575
# step 11800: train loss 1.5889, val loss 1.7479
# step 11900: train loss 1.5982, val loss 1.7436
# step 12000: train loss 1.5839, val loss 1.7535
# step 12100: train loss 1.5878, val loss 1.7613
# step 12200: train loss 1.5903, val loss 1.7630
# step 12300: train loss 1.5779, val loss 1.7603
# step 12400: train loss 1.5980, val loss 1.7574
# step 12500: train loss 1.5972, val loss 1.7542
# step 12600: train loss 1.5987, val loss 1.7477
# step 12700: train loss 1.5953, val loss 1.7469
# step 12800: train loss 1.5870, val loss 1.7687
# step 12900: train loss 1.5879, val loss 1.7702
# step 13000: train loss 1.5857, val loss 1.7676
# step 13100: train loss 1.5840, val loss 1.7487
# step 13200: train loss 1.5860, val loss 1.7483
# step 13300: train loss 1.5823, val loss 1.7497
# step 13400: train loss 1.5864, val loss 1.7397
# step 13500: train loss 1.5810, val loss 1.7592
# step 13600: train loss 1.5866, val loss 1.7569
# step 13700: train loss 1.5767, val loss 1.7490
# step 13800: train loss 1.5809, val loss 1.7517
# step 13900: train loss 1.5785, val loss 1.7479
# step 14000: train loss 1.5737, val loss 1.7496
# step 14100: train loss 1.5753, val loss 1.7542
# step 14200: train loss 1.5746, val loss 1.7473
# step 14300: train loss 1.5722, val loss 1.7490
# step 14400: train loss 1.5664, val loss 1.7404
# step 14500: train loss 1.5745, val loss 1.7291
# step 14600: train loss 1.5732, val loss 1.7394
# step 14700: train loss 1.5802, val loss 1.7346
# step 14800: train loss 1.5843, val loss 1.7362
# step 14900: train loss 1.5750, val loss 1.7357
# step 14999: train loss 1.5686, val loss 1.7414
#
# And to att him succlerels, I'll saw the rag
# plawainer, sir, tewbplings
# Ship to tell judient of thems;
# Were little is be?
#
# KING RAMILLOUCESTIO:
# Then Ssham, must their knews bereahing sendly abseene?
#
# FRIAR LAURENCENTIUS:
# see, young and is seemeds to their Bolick?
#
# JULIET:
# And the Dy Avinges doth be exthies,
# As you they toth sover doth his discrege,
# Aflot, thy regene as leady, abother:
# Again am my doth bound office, while compasse.
#
# Clown:
# But their it thee, we him andtune; wist down the news hers's love:
# I quomb theschage to compey
# Your sees; soly of bloody him tself'd him theirse becse.
#
# First WICillo, assold heary to neither.
#
# GREMEOIONE:
# O, dare you rejur frisels,
# What would thou be movet.
#
# HELORY BEWARD YORK:
# I bed right ouned his
# sumps, and and cumm solding that evenius. has doth my stilf.
#
# JULIET:
# An viowns in within a to many his adladd.
#
# DUKE VINCENTIO:
# And I would you destan ast, but herent,
# Broyst his son you must insomen
# his joyield sour bersely
# We great'sm plosin? My presection sown,
# Are to lieve all to she at abseech sporrow say.
# To is thou, here didsce, breepin of drefence to the at, a pothereit! Bondomied,
# Leak iMARGARIM:
# What's thee me
# I an hath was mine, alwick'd infiturine my with were,
# Then agains on his ancome, poom? That berth hast so demands subjece! the scoweritize, -thy secul hith minestinge
# Is sees yet free, flow thouse peace and againsterly;
# me, butch mines a rewly is my nor wom'd
# To themm of his eich.
# My gods one the great morly poor,
# To his lealn seem clip toke; in mine hee,
# In treamouse made to blead your partinable;
# With it worth wantwick we him
# of long my mads? there
# Thou boyseent for that and the true ed of the strown.
#
# FLORIZINIUS:
# Ay, 'be to saint:
# Of my lords to earlt or lesse,
# For my Lond my browfry spine keep and Isly,
# Margeth sainten Hm this good to exreat.
#
# Secome:
# Stairs is the mack; youga slowmely-va loody frid like.
#
# DUCESLE:
# ComQusticio's nock one, and long forn,
# And l deangs yours I not my brest, betterns: sleep on headfurn

# %%
import torch
random_tensor = torch.rand(2, 3)

# %%
random_tensor
# Out:
# tensor([[0.0157, 0.5114, 0.5448],
#         [0.0139, 0.0737, 0.2442]])

# %%
random_tensor[:,-1].unsqueeze(1)
# Out:
# tensor([[0.5448],
#         [0.2442]])
